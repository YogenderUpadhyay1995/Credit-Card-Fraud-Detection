# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("/content/creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# #spilting the details

# %%
data.Class.value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
legit = data[data.Class == 0]
fraud = data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
Sample_legit = legit.sample(n=492)
Sample_legit.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 20836    31301.0 -1.484637  0.442120  1.012859 -0.398438  0.243162 -0.805448
# 271955  164835.0  1.826200  0.108377 -0.568269  3.871045  0.402040  0.955345
# 245182  152637.0  1.622504 -2.487024 -4.284932 -2.332392  1.771521  2.770760
# 59516    48873.0  1.351336 -0.109732  0.276011  0.286069 -0.205672  0.163379
# 223640  143466.0  1.925032 -0.550584 -0.632249  0.224082 -0.471759 -0.275928
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 20836   0.772429  0.367766 -0.913635  ... -0.235659 -1.277941  0.367037
# 271955 -0.214238  0.175528 -0.173399  ...  0.078794  0.355354  0.026061
# 245182 -0.027525  0.273148 -2.316440  ...  0.356205  0.565821 -0.460469
# 59516  -0.340870 -0.031228 -1.150867  ... -0.701852 -1.494348  0.165840
# 223640 -0.466643  0.012900  1.107861  ... -0.256089 -0.821902  0.412467
#
# ...

# %% [markdown]
# Concatenating or Combining the Data

# %%
Credit_card_data = pd.concat([Sample_legit, fraud], axis=0)

# %%
Credit_card_data.shape
# Out:
# (984, 31)

# %%
Credit_card_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 20836    31301.0 -1.484637  0.442120  1.012859 -0.398438  0.243162 -0.805448
# 271955  164835.0  1.826200  0.108377 -0.568269  3.871045  0.402040  0.955345
# 245182  152637.0  1.622504 -2.487024 -4.284932 -2.332392  1.771521  2.770760
# 59516    48873.0  1.351336 -0.109732  0.276011  0.286069 -0.205672  0.163379
# 223640  143466.0  1.925032 -0.550584 -0.632249  0.224082 -0.471759 -0.275928
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 20836   0.772429  0.367766 -0.913635  ... -0.235659 -1.277941  0.367037
# 271955 -0.214238  0.175528 -0.173399  ...  0.078794  0.355354  0.026061
# 245182 -0.027525  0.273148 -2.316440  ...  0.356205  0.565821 -0.460469
# 59516  -0.340870 -0.031228 -1.150867  ... -0.701852 -1.494348  0.165840
# 223640 -0.466643  0.012900  1.107861  ... -0.256089 -0.821902  0.412467
#
# ...

# %% [markdown]
# Spliting the data

# %%
X= Credit_card_data.drop(columns = "Class")
Y= Credit_card_data["Class"]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (984, 30)
# (984,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %% [markdown]
# Logitics Regression Model

# %%
Model= LogisticRegression()

# %%
Model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluation of Model

# %%
training_data_prediction = Model.predict(X_train)

# %% [markdown]
# Accuracy Check

# %%
# R Squared Method

r2_error = metrics.r2_score(Y_train, training_data_prediction)
print(r2_error)
# Out:
# 0.7610992701672802

# %%
# Mean absoulte method

Mean_absoulte_method = metrics.mean_absolute_error(Y_train, training_data_prediction)
print(Mean_absoulte_method)
# Out:
# 0.05972045743329098

# %% [markdown]
# Predict on Test data

# %%
Training_test_data = Model.predict(X_test)

# %% [markdown]
# Accuracy check of Test data

# %%
# R Squared Method
R2_error_TestData = metrics.r2_score(Y_test, Training_test_data)
print(R2_error_TestData)
# Out:
# 0.7966976264189887

# %%
# mean absoulte Method

Mean_absoulte_method_testdata= metrics.mean_absolute_error(Y_test, Training_test_data)
print(Mean_absoulte_method)
# Out:
# 0.05972045743329098
